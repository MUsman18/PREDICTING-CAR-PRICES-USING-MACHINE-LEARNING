# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use('ggplot')

# %%
car=pd.read_csv('Book11.csv')

# %%
car.head(15)
# Out:
#      0                      name     company  year    Price  kms_driven  \
# 0    4    Ford EcoSport Titanium        Ford  2014  2875000       36000
# 1    5                 Ford Figo        Ford  2012   875000       41000
# 2    7    Ford EcoSport Ambiente        Ford  2016  4150000       24530
# 3    9       Skoda Fabia Classic       Skoda  2010   910000       60000
# 4   15                   Audi A8        Audi  2017  5000000        4000
# 5   16                   Audi Q7        Audi  2014  2500000       16934
# 6   17                 Ford Figo        Ford  2012   875000       41000
# 7   35          Renault Lodgy 85     Renault  2018  3449995       20000
# 8   36       Skoda Yeti Ambition       Skoda  2012  2240000       68000
# 9   38        Renault Duster 110     Renault  2012  2505000       38000
# 10  39         Renault Duster 85     Renault  2013  2449995       27000
# 11  59                 Ford Figo        Ford  2012   875000       41000
# 12  62    Ford EcoSport Ambiente        Ford  2016  4150000       24530
# 13  64        Chevrolet Spark LS   Chevrolet  2010   550000       41000
# 14  65  Volkswagen Polo Highline  Volkswagen  2014  1575000       60000
#
#    fuel_type
# 0     Diesel
# 1     Diesel
# 2     Diesel
# 3     Petrol
# 4     Petrol
# 5     Diesel
# 6     Diesel
# 7     Diesel
# 8     Diesel
# 9     Diesel
# 10    Diesel
# 11    Diesel
# 12    Diesel
# 13    Petrol
# 14    Petrol

# %%
import seaborn as sns

# %%
plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='company',y='Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()

# %%
plt.subplots(figsize=(20,10))
ax=sns.swarmplot(x='year',y='Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()

# %%
sns.relplot(x='kms_driven',y='Price',data=car,height=7,aspect=1.5)
