# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use('ggplot')

# %%
car=pd.read_csv('Book333.csv')

# %%
car = car.query("fuel_type != 'CNG' and fuel_type != 'LPG' and year>=2001 and fuel_type != 'Hybrid'" )

# %%
car.head(20)
# Out:
#                      name company  year    Price  kms_driven fuel_type
# 1            Suzuki Bolan  Suzuki  2006   380000      100000    Petrol
# 3             Suzuki Alto  Suzuki  2010   535000       94000    Petrol
# 4      Toyota Corolla XLI  Toyota  2013  1430000      100000    Petrol
# 5   Toyota Corrolla Altis  Toyota  2012  1620000       80000    Petrol
# 7   Toyota Corrolla Altis  Toyota  2017  2900000       10241    Petrol
# 12           Toyota Passo  Toyota  2006   770000       78000    Petrol
# 15            Suzuki Alto  Suzuki  2005   425000      200000    Petrol
# 19       Honda City IVTEC   Honda  2014  1400000       69500    Petrol
# 26     Toyota Corolla GLI  Toyota  2010  1190000       75000    Petrol
# 27     Toyota Corolla GLI  Toyota  2011  1290000       75000    Petrol
# 29   Nissan Dayz Highway   Nissan  2013  1175000       47000    Petrol
# 30     Toyota Corolla XLI  Toyota  2015  1675000       43000    Petrol
# 33            Suzuki Alto  Suzuki  2006   420000        1000    Petrol
# 34            Toyota Vitz  Toyota  2014  1430000       39000    Petrol
# 39           Toyota Passo  Toyota  2010  1040000       89000    Petrol
# 41      Suzuki Cultus VXR  Suzuki  2001   360000      100000    Petrol
# 42            Toyota Vitz  Toyota  2003  1150000       69000    Petrol
# 45     Toyota Corolla GLI  Toyota  2009  1220000      163000    Petrol
# 48  Toyota Corrolla Altis  Toyota  2004   875000       45000    Petrol
# 50      Suzuki Cultus VXR  Suzuki  2013   840000       65000    Petrol

# %%
car.shape
# Out:
# (1919, 6)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1919 entries, 1 to 2286
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        1919 non-null   object
#  1   company     1919 non-null   object
#  2   year        1919 non-null   int64
#  3   Price       1919 non-null   int64
#  4   kms_driven  1919 non-null   int64
#  5   fuel_type   1919 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 104.9+ KB

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1919 entries, 1 to 2286
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        1919 non-null   object
#  1   company     1919 non-null   object
#  2   year        1919 non-null   int64
#  3   Price       1919 non-null   int64
#  4   kms_driven  1919 non-null   int64
#  5   fuel_type   1919 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 104.9+ KB

# %%
car.describe(include='all')
# Out:
#                name company         year         Price    kms_driven fuel_type
# count          1919    1919  1919.000000  1.919000e+03  1.919000e+03      1919
# unique          237      26          NaN           NaN           NaN         2
# top     Suzuki Alto  Suzuki          NaN           NaN           NaN    Petrol
# freq            160     693          NaN           NaN           NaN      1307
# mean            NaN     NaN  2011.977071  1.816264e+06  5.485760e+04       NaN
# std             NaN     NaN     3.878565  1.815947e+06  9.279458e+04       NaN
# min             NaN     NaN  2001.000000  2.000000e+05  0.000000e+00       NaN
# 25%             NaN     NaN  2010.000000  8.150000e+05  2.900000e+04       NaN
# 50%             NaN     NaN  2013.000000  1.250000e+06  4.320000e+04       NaN
# 75%             NaN     NaN  2015.000000  2.150000e+06  6.025000e+04       NaN
# max             NaN     NaN  2019.000000  1.550000e+07  1.700000e+06       NaN

# %%
car=car[car['Price']<60000000]

# %%
car['company'].unique()
# Out:
# array(['Suzuki', 'Toyota', 'Honda', 'Nissan', 'Daihatsu', 'Mitsubishi',
#        'Chevrolet', 'FAW', 'Hyundai', 'Ford', 'Skoda', 'Audi', 'Renault',
#        'Datsun', 'Suzukii', 'Volkswagen', 'Mini', 'BMW', "Suzuki'",
#        'Fiat', 'Force', 'Mercedes', 'Land', 'Jaguar', 'Jeep', 'Volvo'],
#       dtype=object)

# %%
import seaborn as sns

# %%
plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='company',y='Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# C:\Users\Muhammad Sameer\AppData\Local\Temp\ipykernel_6004\2788130517.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')

# %%
plt.subplots(figsize=(20,10))
ax=sns.swarmplot(x='year',y='Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 7.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 21.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 25.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 39.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 39.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 34.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 48.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 47.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 44.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 43.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 47.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 17.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Muhammad Sameer\AppData\Local\Temp\ipykernel_6004\2542042277.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 7.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 21.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 25.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 39.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 39.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 34.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 48.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 46.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 47.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 32.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 43.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 42.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 46.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 17.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Muhammad Sameer\OneDrive\Documents\fypReal - Copy\FYPENV\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.relplot(x='kms_driven',y='Price',data=car,height=7,aspect=1.5)

# %%
plt.subplots(figsize=(14,7))
sns.boxplot(x='fuel_type',y='Price',data=car)
# Out:
# <Axes: xlabel='fuel_type', ylabel='Price'>

# %%
ax=sns.relplot(x='company',y='Price',data=car,hue='fuel_type',size='year',height=7,aspect=2)
ax.set_xticklabels(rotation=40,ha='right')

# %%
X=car[['name','company','year','kms_driven','fuel_type']]
y=car['Price']

# %%
X
# Out:
#                        name   company  year  kms_driven fuel_type
# 1              Suzuki Bolan    Suzuki  2006      100000    Petrol
# 3               Suzuki Alto    Suzuki  2010       94000    Petrol
# 4        Toyota Corolla XLI    Toyota  2013      100000    Petrol
# 5     Toyota Corrolla Altis    Toyota  2012       80000    Petrol
# 7     Toyota Corrolla Altis    Toyota  2017       10241    Petrol
# ...                     ...       ...   ...         ...       ...
# 2275          Daihatsu Mira  Daihatsu  2013       49000    Petrol
# 2279                 FAW V2       FAW  2016       16900    Petrol
# 2282            Suzuki Alto    Suzuki  2008       35955    Petrol
# 2283      Honda City Aspire     Honda  2006      131389    Petrol
# 2286            Suzuki Alto    Suzuki  2006      116500    Petrol
#
# [1919 rows x 5 columns]

# %%
y.shape
# Out:
# (1919,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),
                                    remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array([' Suzuki Swift', 'Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0',
#        'Audi A6 2.0', 'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7',
#        'BMW 3 Series', 'BMW 5 Series', 'BMW 7 Series', 'BMW X1',
#        'BMW X1 sDrive20d', 'BMW X1 xDrive20d', 'Chevrolet Beat',...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Daihatsu', 'Datsun', 'FAW', 'Fiat',
#        'Force', 'Ford', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mercedes', 'Mini', 'Mitsubishi', 'Nissan', 'Renault', 'Skoda',
#        'Suzuki', "Suzuki'", 'Suzukii', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
#                                                                             array(['Diesel', 'Petrol'], dtype=object)]),
#                                                   ['name', 'company',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5228147827143328

# %%
scores=[]
for i in range(5000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 878

# %%
scores[np.argmax(scores)]
# Out:
# 0.7808718796504943

# %%
pipe.predict(pd.DataFrame(columns=X_test.columns,data=np.array(['Hyundai Santro Xing','Hyundai',2007,45000,'Petrol']).reshape(1,5)))
# Out:
# array([850763.77150238])

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.7808718796504943

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel321.pkl','wb'))

# %%
pipe.predict(pd.DataFrame(columns=['name','company','year','kms_driven','fuel_type'],data=np.array(['Hyundai Santro Xing','Hyundai',2007,45000,'Petrol']).reshape(1,5)))
# Out:
# array([607777.69438529])

# %%
pipe.steps[0][1].transformers[0][1].categories[0]
# Out:
# array([' Suzuki Swift', 'Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0',
#        'Audi A6 2.0', 'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7',
#        'BMW 3 Series', 'BMW 5 Series', 'BMW 7 Series', 'BMW X1',
#        'BMW X1 sDrive20d', 'BMW X1 xDrive20d', 'Chevrolet Beat',
#        'Chevrolet Beat Diesel', 'Chevrolet Beat LS', 'Chevrolet Beat LT',
#        'Chevrolet Beat PS', 'Chevrolet Cruze LTZ', 'Chevrolet Enjoy',
#        'Chevrolet Enjoy 1.4', 'Chevrolet Joy', 'Chevrolet Sail 1.2',
#        'Chevrolet Sail UVA', 'Chevrolet Spark', 'Chevrolet Spark 1.0',
#        'Chevrolet Spark LS', 'Chevrolet Spark LT', 'Chevrolet Tavera LS',
#        'Chevrolet Tavera Neo', 'Daihatsu Cuore', 'Daihatsu Hijet',
#        'Daihatsu Mira', 'Datsun GO T', 'Datsun Go Plus', 'Datsun Redi GO',
#        'FAW V2', 'Fiat Linea Emotion', 'Fiat Petra ELX',
#        'Fiat Punto Emotion', 'Force Motors Force', 'Force Motors One',
#        'Ford EcoSport', 'Ford EcoSport Ambiente',
#        'Ford EcoSport Titanium', 'Ford EcoSport Trend',
#        'Ford Endeavor 4x4', 'Ford Fiesta', 'Ford Fiesta SXi', 'Ford Figo',
#        'Ford Figo Diesel', 'Ford Figo Duratorq', 'Ford Figo Petrol',
#        'Ford Fusion 1.4', 'Ford Ikon 1.3', 'Ford Ikon 1.6',
#        'Honda Accord', 'Honda Amaze', 'Honda Amaze 1.2',
#        'Honda Amaze 1.5', 'Honda BR-V', 'Honda Brio', 'Honda Brio V',
#        'Honda Brio VX', 'Honda City', 'Honda City 1.5',
#        'Honda City Aspire', 'Honda City IDSI', 'Honda City IVTEC',
#        'Honda City SV', 'Honda City VX', 'Honda City ZX',
#        'Honda Civic EXi', 'Honda Civic Prosmetic',
#        'Honda Civic VTi Oriel Prosmatec', 'Honda Jazz S', 'Honda Jazz VX',
#        'Honda Mobilio', 'Honda Mobilio S', 'Honda Vamos', 'Honda WR V',
#        'Honda Zest', 'Hyundai Accent', 'Hyundai Accent Executive',
#        'Hyundai Accent GLE', 'Hyundai Accent GLX', 'Hyundai Creta',
#        'Hyundai Creta 1.6', 'Hyundai Elantra 1.8', 'Hyundai Elantra SX',
#        'Hyundai Elite i20', 'Hyundai Eon', 'Hyundai Eon D',
#        'Hyundai Eon Era', 'Hyundai Eon Magna', 'Hyundai Eon Sportz',
#        'Hyundai Fluidic Verna', 'Hyundai Getz', 'Hyundai Getz GLE',
#        'Hyundai Getz Prime', 'Hyundai Grand i10', 'Hyundai Santro',
#        'Hyundai Santro AE', 'Hyundai Santro Xing',
#        'Hyundai Sonata Transform', 'Hyundai Verna', 'Hyundai Verna 1.4',
#        'Hyundai Verna 1.6', 'Hyundai Verna Fluidic',
#        'Hyundai Verna Transform', 'Hyundai Verna VGT',
#        'Hyundai Xcent Base', 'Hyundai Xcent SX', 'Hyundai i10',
#        'Hyundai i10 Era', 'Hyundai i10 Magna', 'Hyundai i10 Sportz',
#        'Hyundai i20', 'Hyundai i20 Active', 'Hyundai i20 Asta',
#        'Hyundai i20 Magna', 'Hyundai i20 Select', 'Hyundai i20 Sportz',
#        'Jaguar XE XE', 'Jaguar XF 2.2', 'Jeep Wrangler Unlimited',
#        'Land Rover Freelander', 'Mercedes Benz A', 'Mercedes Benz B',
#        'Mercedes Benz C', 'Mercedes Benz GLA', 'Mini Cooper S',
#        'Mitsubishi Lancer', 'Mitsubishi Lancer 1.8',
#        'Mitsubishi Pajero Sport', 'Nissan AD Van', 'Nissan Dayz',
#        'Nissan Dayz Highway ', 'Nissan Dayz Highway Star', 'Nissan March',
#        'Nissan Micra XL', 'Nissan Micra XV', 'Nissan Sunny',
#        'Nissan Sunny XL', 'Nissan Terrano XL', 'Nissan X Trail',
#        'Renault Duster', 'Renault Duster 110', 'Renault Duster 110PS',
#        'Renault Duster 85', 'Renault Duster 85PS', 'Renault Duster RxL',
#        'Renault Kwid', 'Renault Kwid 1.0', 'Renault Kwid RXT',
#        'Renault Lodgy 85', 'Renault Scala RxL', 'Skoda Fabia',
#        'Skoda Fabia 1.2L', 'Skoda Fabia Classic', 'Skoda Laura',
#        'Skoda Octavia Classic', 'Skoda Rapid Elegance',
#        'Skoda Superb 1.8', 'Skoda Yeti Ambition', 'Suzuki 800',
#        'Suzuki A', 'Suzuki APV', 'Suzuki Alto', 'Suzuki Baleno',
#        'Suzuki Bolan', 'Suzuki Celerio', 'Suzuki Ciaz',
#        'Suzuki Cultus VXL', 'Suzuki Cultus VXR', 'Suzuki Dzire',
#        'Suzuki Eeco', 'Suzuki Ertiga', 'Suzuki Esteem', 'Suzuki Estilo',
#        'Suzuki Every', 'Suzuki Kei', 'Suzuki Liana', 'Suzuki Maruti',
#        'Suzuki Mehran VX', 'Suzuki Mehran VXR', 'Suzuki Omni',
#        'Suzuki Ritz', 'Suzuki S', 'Suzuki SX4', 'Suzuki Stingray',
#        'Suzuki Swift', 'Suzuki Versa', 'Suzuki Vitara', 'Suzuki Wagon',
#        'Suzuki Zen', 'Toyota Camry', 'Toyota Corolla',
#        'Toyota Corolla 2.0 D', 'Toyota Corolla Altis',
#        'Toyota Corolla GLI', 'Toyota Corolla H2', 'Toyota Corolla XLI',
#        'Toyota Corrolla Altis', 'Toyota Estima', 'Toyota Etios',
#        'Toyota Etios G', 'Toyota Etios GD', 'Toyota Etios Liva',
#        'Toyota Fortuner', 'Toyota Fortuner 3.0', 'Toyota Hilux',
#        'Toyota Innova 2.0', 'Toyota Innova 2.5', 'Toyota Passo',
#        'Toyota Prado', 'Toyota Premio', 'Toyota Probox', 'Toyota Qualis',
#        'Toyota Rush', 'Toyota Surf', 'Toyota Vitz', 'Toyota Yaris',
#        'Volkswagen Jetta Comfortline', 'Volkswagen Jetta Highline',
#        'Volkswagen Passat Diesel', 'Volkswagen Polo',
#        'Volkswagen Polo Comfortline', 'Volkswagen Polo Highline',
#        'Volkswagen Polo Highline1.2L', 'Volkswagen Polo Trendline',
#        'Volkswagen Vento Comfortline', 'Volkswagen Vento Highline',
#        'Volkswagen Vento Konekt', 'Volvo S80 Summum'], dtype=object)
